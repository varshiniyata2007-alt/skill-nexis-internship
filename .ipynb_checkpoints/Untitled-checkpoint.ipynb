# %%
print("Hello")
# Out:
# Hello

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'archive.zip',
#  'HelloWorld.ipynb',
#  'ml.ipynb',
#  'mlp1.ipynb',
#  'music.csv',
#  'python-supplementary-materials-main.zip',
#  'transactions.xlsx',
#  'Untitled.ipynb',
#  'vgsales.csv']

# %%
import os
print(os.getcwd())
